# %% [markdown]
# <center>
#     <h1>Mohamed Nasser Aboelnasr</h1>
# </center>

# %% [markdown]
# # Loading packages

# %%
import numpy as np
from sklearn import datasets
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture

# %% [markdown]
# # Creating dataset

# %%
X, y = datasets.make_blobs(n_samples=1500,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=170)

# %%
plt.style.use('ggplot')
plt.figure(figsize=(15,8))
plt.scatter(X[:,0], X[:,1])
plt.title("Dataset")
plt.show()

# %% [markdown]
# # **Implementation of Gaussian Mixture models**

# %% [markdown]
# > # With **2 clusters**

# %%
gm = GaussianMixture(n_components=2, random_state=0)

# %%
gm.fit(X)
# Out:
# GaussianMixture(n_components=2, random_state=0)

# %% [markdown]
# > # Predict the cluster

# %%
gm.predict(X)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
gm.predict_proba(X)
# Out:
# array([[1.00000000e+00, 1.01729221e-11],
#        [9.99999993e-01, 6.67799555e-09],
#        [1.78845174e-05, 9.99982115e-01],
#        ...,
#        [1.00000000e+00, 5.53003971e-27],
#        [1.00000000e+00, 9.23075599e-26],
#        [1.00000000e+00, 4.23712430e-29]])

# %% [markdown]
# > # View Parameters

# %%
gm.means_
# Out:
# array([[-1.23348273,  0.23876284],
#        [-8.90854128, -5.45657118]])

# %%
gm.covariances_
# Out:
# array([[[13.25157207,  0.5448418 ],
#         [ 0.5448418 ,  2.70828311]],
#
#        [[ 1.13620363,  0.02800732],
#         [ 0.02800732,  0.97197133]]])

# %%
gm.weights_
# Out:
# array([0.66042128, 0.33957872])

# %% [markdown]
# # Visualizing dataset

# %%
plt.style.use('ggplot')
plt.figure(figsize=(15,8))
plt.scatter(X[:,0], X[:,1], c=gm.predict(X))
plt.title(f"Clustered Dataset with {gm.n_components} clusters")
plt.show()

# %% [markdown]
# > # With **3 clusters**

# %%
gm = GaussianMixture(n_components=3, random_state=0)

# %%
gm.fit(X)
# Out:
# GaussianMixture(n_components=3, random_state=0)

# %% [markdown]
# > # Predict the cluster

# %%
gm.predict(X)
# Out:
# array([2, 2, 1, ..., 0, 0, 0])

# %%
gm.predict_proba(X)
# Out:
# array([[5.93858015e-061, 8.23261068e-013, 1.00000000e+000],
#        [1.56484543e-082, 1.37630525e-009, 9.99999999e-001],
#        [1.09549628e-203, 9.97564718e-001, 2.43528163e-003],
#        ...,
#        [9.94458372e-001, 1.32949568e-031, 5.54162826e-003],
#        [9.34469404e-001, 2.68374773e-029, 6.55305956e-002],
#        [9.98360072e-001, 2.08396627e-034, 1.63992824e-003]])

# %% [markdown]
# > # View Parameters

# %%
gm.means_
# Out:
# array([[ 1.92228999,  0.45614336],
#        [-8.95577131, -5.48509192],
#        [-4.49503928, -0.09394217]])

# %%
gm.covariances_
# Out:
# array([[[ 2.31830343e-01,  6.14036899e-03],
#         [ 6.14036899e-03,  2.42786828e-01]],
#
#        [[ 1.02267848e+00, -1.40842473e-02],
#         [-1.40842473e-02,  9.38863935e-01]],
#
#        [[ 6.23130532e+00, -1.39207356e-02],
#         [-1.39207356e-02,  5.48329133e+00]]])

# %%
gm.weights_
# Out:
# array([0.33213049, 0.33091445, 0.33695505])

# %% [markdown]
# # Visualizing dataset

# %%
plt.style.use('ggplot')
plt.figure(figsize=(15,8))
plt.scatter(X[:,0], X[:,1], c=gm.predict(X))
plt.title(f"Clustered Dataset with {gm.n_components} clusters")
plt.show()
